# %%
import Library_hm3_repo
from Library_hm3_repo.lib3.EDA import pop_parameters, numeric_cols, plot_hist_mult, explore
import pandas as pd
import numpy as np
import os
from IPython.display import display
from sklearn.model_selection import train_test_split

# %%
path = os.getcwd()

# %%
#  Load Data
df = pd.read_csv(path+'/sample_diabetes_mellitus_data.csv')

# %%
explore(df,9,3,3)
# Out:
# Summary Statistics
#               Unnamed: 0 encounter_id hospital_id      age      bmi  \
# size               10000        10000       10000    10000    10000
# datatype           int64        int64       int64  float64  float64
# unique_values      10000        10000          26       75     5983
# mean              4999.5    212388.14      103.05    62.41    29.78
# stdv             2886.75     38024.71       30.92     16.6     8.37
# min                  0.0     147009.0         4.0     16.0    14.84
# per25            2499.75     179460.0        83.0     53.0    23.95
# median            4999.5     211995.5       118.0     64.0     28.2
# per75            7499.25    245350.25       118.0     75.0    33.75
# max               9999.0     279000.0       198.0     89.0    67.81
# IQRs              4999.5     65890.25        35.0     22.0      9.8
# lower_bound          0.0     80624.62        30.5     20.0     9.24
# upper_bound      14998.5    344185.62       170.5    108.0    48.46
#
#               elective_surgery   height  icu_id pre_icu_los_days
# size                     10000    10000   10000            10000
# datatype                 int64  float64   int64          float64
# unique_values                2      175      35             2201
# mean                      0.23    169.9  105.66             0.64
# stdv                      0.42    10.72   17.86             2.13
# min                        0.0    137.2    82.0            -0.22
# per25                      0.0    162.6    92.0              0.0
# median                     0.0    170.2    99.0             0.01
# per75                      0.0    177.8   114.0             0.17
# max                        1.0   195.59   171.0            49.52
# IQRs                       0.0     15.2    22.0             0.16
# lower_bound                0.0    139.8    59.0            -0.24
# upper_bound                0.0    200.6   147.0             0.41
# histograms
