# %%
import Library_hm3_repo
from Library_hm3_repo.lib3.EDA import pop_parameters, numeric_cols
import pandas as pd
import numpy as np
import os

# %%
path = os.getcwd()

# %%
df = pd.read_csv(path+'/sample_diabetes_mellitus_data.csv')

# %%
# Only numeric columns
num = numeric_cols(df)

# %%
pop_parameters(df[num])
# Out:
#                               size datatype  unique_values       mean  \
# Unnamed: 0                   10000    int64          10000    4999.50
# encounter_id                 10000    int64          10000  212388.14
# hospital_id                  10000    int64             26     103.05
# age                          10000  float64             75      62.41
# bmi                          10000  float64           5983      29.78
# elective_surgery             10000    int64              2       0.23
# height                       10000  float64            175     169.90
# icu_id                       10000    int64             35     105.66
# pre_icu_los_days             10000  float64           2201       0.64
# readmission_status           10000    int64              1       0.00
# weight                       10000  float64           1370      86.10
# albumin_apache               10000  float64             36       2.82
# ...
